# %%
import pandas as pd
import numpy as np

# %%
#Cleaning up the cells geo dataset
geo = pd.read_csv('cells_geo.csv', index_col = 0)
geo.head()
# Out:
#     VILLES      STATUS LOCALISATION    DECOUPZONE  ZONENAME  LONGITUDE  \
# 0   ADJAME  In Service      ABIDJAN  "Abidjan_EST  AGBANNEW  -4.000667
# 1   ADJAME  In Service      ABIDJAN  "Abidjan_EST  AGBANNEW  -4.000667
# 2   ADJAME  In Service      ABIDJAN  "Abidjan_EST  AGBANNEW  -4.000667
# 3  ASSINIE  In Service    INTERIEUR     Grand-EST  ASSINIE"  -3.488467
# 4  ASSINIE  In Service    INTERIEUR     Grand-EST  ASSINIE"  -3.488467
#
#    LATITUDE     REGION AREA     CELL_ID   SITE_CODE
# 0  5.368194     LAGUNE  NaN  fbb2e75af3  0bb492ef17
# 1  5.368194     LAGUNE  NaN  1502501d78  0bb492ef17
# 2  5.368194     LAGUNE  NaN  0c2e182a0c  0bb492ef17
# 3  5.158761  SUD COMOE  NaN  69bdfc69fd  8a1e6ce31f
# 4  5.158761  SUD COMOE  NaN  7a1029d2ab  8a1e6ce31f

# %%
df = pd.DataFrame(geo)
df.head()
# Out:
#     VILLES      STATUS LOCALISATION    DECOUPZONE  ZONENAME  LONGITUDE  \
# 0   ADJAME  In Service      ABIDJAN  "Abidjan_EST  AGBANNEW  -4.000667
# 1   ADJAME  In Service      ABIDJAN  "Abidjan_EST  AGBANNEW  -4.000667
# 2   ADJAME  In Service      ABIDJAN  "Abidjan_EST  AGBANNEW  -4.000667
# 3  ASSINIE  In Service    INTERIEUR     Grand-EST  ASSINIE"  -3.488467
# 4  ASSINIE  In Service    INTERIEUR     Grand-EST  ASSINIE"  -3.488467
#
#    LATITUDE     REGION AREA     CELL_ID   SITE_CODE
# 0  5.368194     LAGUNE  NaN  fbb2e75af3  0bb492ef17
# 1  5.368194     LAGUNE  NaN  1502501d78  0bb492ef17
# 2  5.368194     LAGUNE  NaN  0c2e182a0c  0bb492ef17
# 3  5.158761  SUD COMOE  NaN  69bdfc69fd  8a1e6ce31f
# 4  5.158761  SUD COMOE  NaN  7a1029d2ab  8a1e6ce31f

# %%
df.shape
# Out:
# (3974, 11)

# %%
#converting the column names into lower case
df.columns = map(str.lower, df.columns)
df.columns
# Out:
# Index(['villes', 'status', 'localisation', 'decoupzone', 'zonename',
#        'longitude', 'latitude', 'region', 'area', 'cell_id', 'site_code'],
#       dtype='object')

# %%
#renaming the column names of villes and site id
df.rename(columns = {'villes':'cities','site_code':'site_id'}, inplace = True)
df.columns
# Out:
# Index(['cities', 'status', 'localisation', 'decoupzone', 'zonename',
#        'longitude', 'latitude', 'region', 'area', 'cell_id', 'site_id'],
#       dtype='object')

# %%
df.drop(['decoupzone', 'zonename','longitude', 'latitude', 'area'], axis = 1, inplace = True)
df.head()
# Out:
#     cities      status localisation     region     cell_id     site_id
# 0   ADJAME  In Service      ABIDJAN     LAGUNE  fbb2e75af3  0bb492ef17
# 1   ADJAME  In Service      ABIDJAN     LAGUNE  1502501d78  0bb492ef17
# 2   ADJAME  In Service      ABIDJAN     LAGUNE  0c2e182a0c  0bb492ef17
# 3  ASSINIE  In Service    INTERIEUR  SUD COMOE  69bdfc69fd  8a1e6ce31f
# 4  ASSINIE  In Service    INTERIEUR  SUD COMOE  7a1029d2ab  8a1e6ce31f

# %%
df.isnull().sum()
# Out:
# cities           0
# status          67
# localisation     0
# region           0
# cell_id          0
# site_id          0
# dtype: int64

# %%
df.status.fillna(df.status.mode()[0], inplace = True)
df.isnull().sum()
# Out:
# cities          0
# status          0
# localisation    0
# region          0
# cell_id         0
# site_id         0
# dtype: int64

# %%
moringa = pd.read_csv('MoringaSchool_CB_CDR_20120507.csv')
moringa
# Out:
#          PRODUTC  VALUE               DATETIME CELL_ON_SITE  DW_A_NUMBER_INT  \
# 0          Voice      0  2012-05-06 23:04:37.0            1  49fae048b547780
# 1            sms      0  2012-05-06 23:05:25.0            0  7a54a6eaee19e65
# 2            sms     25  2012-05-06 23:05:41.0            0  6008887b0207d82
# 3          Voice     56  2012-05-06 23:05:42.0            1  7370032e20f4e96
# 4          Voice     14  2012-05-06 23:06:29.0            1  966ba4656e38e62
# 5           data      0  2012-05-06 23:07:26.0            _  f71825ca6e623f9
# 6          Voice      0  2012-05-06 23:08:02.0            1  4afd7d5af21b1ce
# 7          Voice      0  2012-05-06 23:08:03.0            5  d717dee81c51389
# 8          Voice      0  2012-05-06 23:08:05.0            1  44522aefdc918a6
# 9            sms      0  2012-05-06 23:08:43.0            0  0763a571d24db64
# 10           sms      0  2012-05-06 23:08:50.0            2  93105314189e879
# ...

# %%
df1 = pd.DataFrame(moringa)
df1.head()
# Out:
#   PRODUTC  VALUE               DATETIME CELL_ON_SITE  DW_A_NUMBER_INT  \
# 0   Voice      0  2012-05-06 23:04:37.0            1  49fae048b547780
# 1     sms      0  2012-05-06 23:05:25.0            0  7a54a6eaee19e65
# 2     sms     25  2012-05-06 23:05:41.0            0  6008887b0207d82
# 3   Voice     56  2012-05-06 23:05:42.0            1  7370032e20f4e96
# 4   Voice     14  2012-05-06 23:06:29.0            1  966ba4656e38e62
#
#    DW_B_NUMBER_INT COUNTRY_A COUNTRY_B     CELL_ID     SITE_ID
# 0  1a49f8b0ded9de6     19e2e     19e2e  /TJNe+Mmtu  /TJNe+Mmtu
# 1  93343ba6e41af95     19e2e     19e2e  /+cKZKIp41  /+cKZKIp41
# 2  7aacc9709ce0a20     19e2e     19e2e  /u0FSD+ahi  /u0FSD+ahi
# 3  6af4a60e74c91d3     19e2e     19e2e  +cNeJzsTp3  +cNeJzsTp3
# 4  02aa736ee555d5c     19e2e     19e2e  051KhYDCpv  051KhYDCpv

# %%
df1.columns = map(str.lower, df1.columns)
df1.columns
# Out:
# Index(['produtc', 'value', 'datetime', 'cell_on_site', 'dw_a_number_int',
#        'dw_b_number_int', 'country_a', 'country_b', 'cell_id', 'site_id'],
#       dtype='object')

# %%
df1.shape
# Out:
# (15011816, 10)

# %%
df1.rename(columns={'produtc':'product', 'datetime':'date_time'}, inplace = True)

# %%
df1.columns
# Out:
# Index(['product', 'value', 'date_time', 'cell_on_site', 'dw_a_number_int',
#        'dw_b_number_int', 'country_a', 'country_b', 'cell_id', 'site_id'],
#       dtype='object')

# %%
df1.drop(['cell_on_site','dw_a_number_int','dw_b_number_int','country_a','country_b'], axis = 1, inplace = True)
df1.head()
# Out:
#   product  value              date_time     cell_id     site_id
# 0   Voice      0  2012-05-06 23:04:37.0  /TJNe+Mmtu  /TJNe+Mmtu
# 1     sms      0  2012-05-06 23:05:25.0  /+cKZKIp41  /+cKZKIp41
# 2     sms     25  2012-05-06 23:05:41.0  /u0FSD+ahi  /u0FSD+ahi
# 3   Voice     56  2012-05-06 23:05:42.0  +cNeJzsTp3  +cNeJzsTp3
# 4   Voice     14  2012-05-06 23:06:29.0  051KhYDCpv  051KhYDCpv

# %%
df1.isnull().sum()
# Out:
# product           0
# value             0
# date_time         0
# cell_id           0
# site_id      540033
# dtype: int64

# %%
df1.site_id.fillna(df.site_id.mode()[0], inplace = True)
df1.isnull().sum()
# Out:
# product      0
# value        0
# date_time    0
# cell_id      0
# site_id      0
# dtype: int64

# %%
moringa2 = pd.read_csv('MoringaSchool_CB_CDR_20120508.csv')
moringa2
# Out:
#          PRODUCT  VALUE              DATE_TIME CELL_ON_SITE      DW_A_NUMBER  \
# 0            sms      0  2012-05-07 23:02:06.0            2  32255675c3b6fe3
# 1          Voice      0  2012-05-07 23:03:44.0            1  ff16d6ac74c1c64
# 2            sms      0  2012-05-07 23:04:06.0            0  98d9f2fb5ff624b
# 3          Voice     37  2012-05-07 23:04:48.0            1  3f9c8a33ec7be1f
# 4            sms     25  2012-05-07 23:04:58.0            1  7bcccc03adf3864
# 5            sms      0  2012-05-07 23:05:41.0            4  d73f11fdc9fcb30
# 6          Voice     41  2012-05-07 23:06:14.0            1  eafaf521153b405
# 7          Voice     11  2012-05-07 23:06:28.0            0  a1799cdc5108a90
# 8            sms      0  2012-05-07 23:06:35.0            2  f81bb99db8c0373
# 9            sms      0  2012-05-07 23:06:50.0            0  6a7d89469dc20e9
# 10           sms      0  2012-05-07 23:06:58.0            0  81dff572800e83b
# ...

# %%
df2 = pd.DataFrame(moringa2)
df2.head()
# Out:
#   PRODUCT  VALUE              DATE_TIME CELL_ON_SITE      DW_A_NUMBER  \
# 0     sms      0  2012-05-07 23:02:06.0            2  32255675c3b6fe3
# 1   Voice      0  2012-05-07 23:03:44.0            1  ff16d6ac74c1c64
# 2     sms      0  2012-05-07 23:04:06.0            0  98d9f2fb5ff624b
# 3   Voice     37  2012-05-07 23:04:48.0            1  3f9c8a33ec7be1f
# 4     sms     25  2012-05-07 23:04:58.0            1  7bcccc03adf3864
#
#        DW_B_NUMBER COUNTRY_A COUNTRY_B     CELL_ID     SITE_ID
# 0  1aa7ae01386e9fb     19e2e     19e2e  +854AcBQT2  +854AcBQT2
# 1  87d87309c15a8c9     19e2e     19e2e  +854AcBQT2  +854AcBQT2
# 2  93343ba6e41af95     19e2e     19e2e  +laSrk7g6q  +laSrk7g6q
# 3  7d05a38f89c49d8     19e2e     19e2e  /xvRrCVKoQ  /xvRrCVKoQ
# 4  56a5d5430d2fa86     19e2e     19e2e  +bO+qkSonO  +bO+qkSonO

# %%
df2.shape
# Out:
# (19606112, 10)

# %%
df2.columns = map(str.lower, df2.columns)
df2.columns
# Out:
# Index(['product', 'value', 'date_time', 'cell_on_site', 'dw_a_number',
#        'dw_b_number', 'country_a', 'country_b', 'cell_id', 'site_id'],
#       dtype='object')

# %%
df2.drop(['cell_on_site','dw_a_number','dw_b_number','country_a','country_b'], axis = 1, inplace = True)
df2.head()
# Out:
#   product  value              date_time     cell_id     site_id
# 0     sms      0  2012-05-07 23:02:06.0  +854AcBQT2  +854AcBQT2
# 1   Voice      0  2012-05-07 23:03:44.0  +854AcBQT2  +854AcBQT2
# 2     sms      0  2012-05-07 23:04:06.0  +laSrk7g6q  +laSrk7g6q
# 3   Voice     37  2012-05-07 23:04:48.0  /xvRrCVKoQ  /xvRrCVKoQ
# 4     sms     25  2012-05-07 23:04:58.0  +bO+qkSonO  +bO+qkSonO

# %%
df2.isnull().sum()
# Out:
# product           0
# value             0
# date_time         0
# cell_id           0
# site_id      521178
# dtype: int64

# %%
df2.site_id.fillna(df.site_id.mode()[0], inplace = True)
df2.isnull().sum()
# Out:
# product      0
# value        0
# date_time    0
# cell_id      0
# site_id      0
# dtype: int64

# %%
moringa3 = pd.read_csv('MoringaSchool_CB_CDR_20120509.csv')
moringa3
# Out:
#          PRODUCT  VALUE              DATE_TIME CELL_ON_SITE  DW_A_NUMBER_INT  \
# 0          Voice     61  2012-05-08 23:01:28.0            2  966f68353622feb
# 1            sms      0  2012-05-08 23:01:31.0            1  a0a597384c612d7
# 2          Voice     10  2012-05-08 23:02:59.0            1  5441a9a58c97132
# 3            sms      0  2012-05-08 23:03:04.0            0  8ab8b9ed6989f61
# 4          Voice     22  2012-05-08 23:03:16.0            4  52662a62b199334
# 5          Voice     10  2012-05-08 23:03:59.0            0  c572f692ed9d25f
# 6            sms      0  2012-05-08 23:06:06.0            0  32cc9a0c68cc9ee
# 7          Voice     10  2012-05-08 23:06:55.0            1  38c234bf93b3aac
# 8            sms     25  2012-05-08 23:07:09.0            1  6dd0d088cceca75
# 9            sms      0  2012-05-08 23:07:38.0            0  9572b11240ca426
# 10           sms      0  2012-05-08 23:07:43.0            2  5b6f26b5d0758fe
# ...

# %%
df3 = pd.DataFrame(moringa3)
df3.head()
# Out:
#   PRODUCT  VALUE              DATE_TIME CELL_ON_SITE  DW_A_NUMBER_INT  \
# 0   Voice     61  2012-05-08 23:01:28.0            2  966f68353622feb
# 1     sms      0  2012-05-08 23:01:31.0            1  a0a597384c612d7
# 2   Voice     10  2012-05-08 23:02:59.0            1  5441a9a58c97132
# 3     sms      0  2012-05-08 23:03:04.0            0  8ab8b9ed6989f61
# 4   Voice     22  2012-05-08 23:03:16.0            4  52662a62b199334
#
#    DW_B_NUMBER_INT COUNTRY_A COUNTRY_B      CELLID     SIET_ID
# 0  ffd53a3bb2db6f1     19e2e     19e2e  +38u2u/rfx  +38u2u/rfx
# 1  cf3b218f1dde792     19e2e     19e2e  +Fs4mTvdKx  +Fs4mTvdKx
# 2  52f8b299515b9b7     19e2e     19e2e  +ZaaZozy/+  +ZaaZozy/+
# 3  e09e736e46c5c3d     19e2e     19e2e  +cNeJzsTp3  +cNeJzsTp3
# 4  2186273faab4602     19e2e     19e2e  /eeMklgyJA  /eeMklgyJA

# %%
df3.shape
# Out:
# (14834801, 10)

# %%
df3.columns = map(str.lower, df3.columns)
df3.columns
# Out:
# Index(['product', 'value', 'date_time', 'cell_on_site', 'dw_a_number_int',
#        'dw_b_number_int', 'country_a', 'country_b', 'cellid', 'siet_id'],
#       dtype='object')

# %%
df3.rename(columns={'cellid':'cell_id', 'siet_id':'site_id'}, inplace = True)
df3.columns
# Out:
# Index(['product', 'value', 'date_time', 'cell_on_site', 'dw_a_number_int',
#        'dw_b_number_int', 'country_a', 'country_b', 'cell_id', 'site_id'],
#       dtype='object')

# %%
df3.drop(['cell_on_site','dw_a_number_int','dw_b_number_int','country_a','country_b'], axis = 1, inplace = True)
df3.head()
# Out:
#   product  value              date_time     cell_id     site_id
# 0   Voice     61  2012-05-08 23:01:28.0  +38u2u/rfx  +38u2u/rfx
# 1     sms      0  2012-05-08 23:01:31.0  +Fs4mTvdKx  +Fs4mTvdKx
# 2   Voice     10  2012-05-08 23:02:59.0  +ZaaZozy/+  +ZaaZozy/+
# 3     sms      0  2012-05-08 23:03:04.0  +cNeJzsTp3  +cNeJzsTp3
# 4   Voice     22  2012-05-08 23:03:16.0  /eeMklgyJA  /eeMklgyJA

# %%
df3.isnull().sum()
# Out:
# product           0
# value             0
# date_time         0
# cell_id           0
# site_id      558367
# dtype: int64

# %%
df3.site_id.fillna(df.site_id.mode()[0], inplace = True)
df3.isnull().sum()
# Out:
# product      0
# value        0
# date_time    0
# cell_id      0
# site_id      0
# dtype: int64

# %%
#concating the three datasets,Moringa 1,Moringa 2,Moringa3
moringas = pd.concat([df1,df2,df3], ignore_index = True, sort = True)
moringas.tail(10)
# Out:
#              cell_id              date_time product     site_id  value
# 49452719  xj10st71q2  2012-05-10 00:53:21.0   Voice  xj10st71q2     33
# 49452720  xqKepCu/mP  2012-05-10 00:53:33.0     sms  xqKepCu/mP      0
# 49452721  yf1PVM0Ir0  2012-05-10 00:53:54.0     sms  yf1PVM0Ir0      0
# 49452722  zcj81as8v9  2012-05-10 00:53:54.0     sms  zcj81as8v9     50
# 49452723  wyCwF9ZnJm  2012-05-10 00:54:14.0     sms  wyCwF9ZnJm      0
# 49452724  zsA2dnzCR5  2012-05-10 00:55:42.0   Voice  zsA2dnzCR5     14
# 49452725  xxbbz32oIL  2012-05-10 00:55:51.0     sms  xxbbz32oIL      0
# 49452726  zbVRn1hiwe  2012-05-10 00:55:53.0     sms  zbVRn1hiwe      0
# 49452727  yPq8TPd7WC  2012-05-10 00:57:11.0     sms  yPq8TPd7WC     25
# 49452728  zqHx55Evcc  2012-05-10 00:59:04.0     sms  zqHx55Evcc      0

# %%
moringas.shape
# Out:
# (49452729, 5)

# %%
moringas.columns
# Out:
# Index(['cell_id', 'date_time', 'product', 'site_id', 'value'], dtype='object')

# %%
#checks which columns if any has missing values
df.columns[df.isnull().any()]
# Out:
# Index([], dtype='object')

# %%
#dropping all rows that have a value = 0
moringas.drop(moringas.loc[moringas['value']==0].index, inplace=True)

# %%
moringas.head()
# Out:
#        cell_id              date_time product     site_id  value
# 2   /u0FSD+ahi  2012-05-06 23:05:41.0     sms  /u0FSD+ahi     25
# 3   +cNeJzsTp3  2012-05-06 23:05:42.0   Voice  +cNeJzsTp3     56
# 4   051KhYDCpv  2012-05-06 23:06:29.0   Voice  051KhYDCpv     14
# 13  2dmu2Iy1CX  2012-05-06 23:09:16.0     sms  2dmu2Iy1CX     25
# 16  ++ctND+jGD  2012-05-06 23:09:54.0   Voice  ++ctND+jGD     44

# %%
moringas.shape
# Out:
# (25618916, 5)

# %%
moringas.dtypes
# Out:
# cell_id      object
# date_time    object
# product      object
# site_id      object
# value         int64
# dtype: object

# %%
#convert the date time column to datetime datatype
moringas.date_time = pd.to_datetime(moringas.date_time)

# %%
#splitting date_time to date and time
moringas['date'] = [d.date() for d in moringas.date_time]

# %%
moringas.columns
# Out:
# Index(['cell_id', 'date_time', 'product', 'site_id', 'value', 'date'], dtype='object')

# %%
moringas['time'] = [d.time() for d in moringas.date_time]

# %%
moringas.columns
# Out:
# Index(['cell_id', 'date_time', 'product', 'site_id', 'value', 'date', 'time'], dtype='object')

# %%
mergedsample = df.merge(moringas, how='inner', left_on='cell_id', right_on='site_id')
mergedsample
# Out:
#            cities      status localisation     region   cell_id_x   site_id_x  \
# 0         ASSINIE  In Service    INTERIEUR  SUD COMOE  69bdfc69fd  8a1e6ce31f
# 1         ASSINIE  In Service    INTERIEUR  SUD COMOE  69bdfc69fd  8a1e6ce31f
# 2         ASSINIE  In Service    INTERIEUR  SUD COMOE  69bdfc69fd  8a1e6ce31f
# 3         ASSINIE  In Service    INTERIEUR  SUD COMOE  69bdfc69fd  8a1e6ce31f
# 4         ASSINIE  In Service    INTERIEUR  SUD COMOE  69bdfc69fd  8a1e6ce31f
# 5         ASSINIE  In Service    INTERIEUR  SUD COMOE  69bdfc69fd  8a1e6ce31f
# 6         ASSINIE  In Service    INTERIEUR  SUD COMOE  69bdfc69fd  8a1e6ce31f
# 7         ASSINIE  In Service    INTERIEUR  SUD COMOE  69bdfc69fd  8a1e6ce31f
# 8         ASSINIE  In Service    INTERIEUR  SUD COMOE  69bdfc69fd  8a1e6ce31f
# 9         ASSINIE  In Service    INTERIEUR  SUD COMOE  69bdfc69fd  8a1e6ce31f
# 10        ASSINIE  In Service    INTERIEUR  SUD COMOE  69bdfc69fd  8a1e6ce31f
# ...

# %%
#Analysis of the merged data
#product usage for all days
mergedsample.groupby(['date', 'product'])['product'].count().sort_values(ascending = False)
# Out:
# date        product
# 2012-05-07  Voice      2980130
# 2012-05-09  Voice      2877173
# 2012-05-08  Voice      2771493
#             sms         116539
# 2012-05-09  sms         105611
# 2012-05-07  sms         102892
#             data         47701
# 2012-05-09  data         46406
# Name: product, dtype: int64

# %%
x = mergedsample.groupby(['cities', 'product'])['product'].count().sort_values(ascending = False)
x
# Out:
# cities         product
# BOUAKE         Voice      1115872
# SAN-PEDRO      Voice       666323
# DALOA          Voice       420432
# ABOBO          Voice       362897
# MAN            Voice       360029
# DIVO           Voice       347722
# BOUNA          Voice       347008
# GRAND-BASSAM   Voice       252949
# ASSINIE        Voice       242145
# DABOU          Voice       236680
# COCODY         Voice       209612
# AGNIBILEKRO    Voice       196619
# ADZOPE         Voice       193674
# DAOUKRO        Voice       170168
# GAGNOA         Voice       156245
# DABAKALA       Voice       146057
# ABOISSO        data        140796
# BONOUA         Voice       138267
# DJEMISSIKRO    Voice       135146
# BOUNDIALI      Voice       120258
# YAMOUSSOUKRO   Voice       117134
# ABOISSO        Voice       112248
# DJEBONOUA      Voice       107054
# BOUAFLE        Voice       100125
# N'ZIKRO        Voice        96842
# GRAND BEREBY   Voice        95494
# NOE            Voice        94688
# ...

# %%
mergedsample.groupby(['region', 'product'])['product'].count().sort_values(ascending = False)
# Out:
# region             product
# LAGUNE             Voice      1860021
# VALLEE DU BANDAMA  Voice      1410698
# BAS SASSANDRA      Voice       874943
# SUD COMOE          Voice       831279
# HAUT SASSANDRA     Voice       460047
# SUD BANDAMA        Voice       410068
# ZANZAN             Voice       365732
# 18 MONTAGNES       Voice       360039
# NZI COMOE          Voice       295319
# FROMAGER           Voice       285147
# MARAHOUE           Voice       277041
# AGNEBY             Voice       266768
# SAVANE             Voice       259856
# MOYEN COMOE        Voice       256538
# LACS               Voice       210924
# SUD COMOE          data         94107
# WORODOUGOU         Voice        85067
# LAGUNE             sms          78300
# MOYEN CAVALLY      Voice        67609
# VALLEE DU BANDAMA  sms          63985
# DENGUELE           Voice        51698
# SUD COMOE          sms          30747
# BAS SASSANDRA      sms          25481
# HAUT SASSANDRA     sms          18799
# ...

# %%
mergedsample['date'] =  pd.to_datetime(mergedsample['date'],format='%Y-%m-%d', errors = 'ignore')

# %%
mergedsample['time'] =  pd.to_datetime(mergedsample['time'],format='%H:%M:%S:%f', errors = 'ignore')

# %%
mergedsample.rename(columns= {'date_time':'datetime'}, inplace = True)

# %%
mergedsample.columns
# Out:
# Index(['cities', 'status', 'localisation', 'region', 'cell_id_x', 'site_id_x',
#        'cell_id_y', 'datetime', 'product', 'site_id_y', 'value', 'date',
#        'time'],
#       dtype='object')

# %%
import datetime as dt

# %%
workinghrs.groupby('cities')['cities'].count().sort_values(ascending = False)
# Out:
# cities
# BOUAKE           560598
# SAN-PEDRO        307811
# DALOA            196877
# MAN              170315
# ABOBO            162163
# DIVO             160311
# BOUNA            157460
# GRAND-BASSAM     128194
# DABOU            120041
# ASSINIE          117487
# ABOISSO          109606
# AGNIBILEKRO      100485
# COCODY            96774
# ADZOPE            95083
# DJEMISSIKRO       83732
# DAOUKRO           76642
# BONOUA            74747
# DABAKALA          72090
# GAGNOA            61222
# BOUNDIALI         60810
# DJEBONOUA         57150
# BOUAFLE           51704
# YAMOUSSOUKRO      48300
# N'ZIKRO           44271
# BONON             42692
# GRAND BEREBY      42199
# NOE               41582
# SEGUELA           40680
# ATTINGUIE         40399
# DIEGONEFLA        38801
#                   ...
# KRINJABO              7
# DIDIEVI               7
# BOCANDA               6
# TIASSALE              6
# DIABO                 5
# RUBINO                5
# BANGOLO               5
# ...

# %%
#working hrs between 8 and 5

import datetime

workinghrs =mergedsample[(mergedsample.datetime.dt.time >= datetime.time(8)) & (mergedsample.datetime.dt.time <= datetime.time(17))]

workinghrs.head()

#mergedsample[(mergedsample.datetime.dt.time >= datetime.time(8)) & (mergedsample.datetime.dt.time <= datetime.time(17))]
# Out:
#        cities      status localisation     region   cell_id_x   site_id_x  \
# 1503  ASSINIE  In Service    INTERIEUR  SUD COMOE  69bdfc69fd  8a1e6ce31f
# 1504  ASSINIE  In Service    INTERIEUR  SUD COMOE  69bdfc69fd  8a1e6ce31f
# 1505  ASSINIE  In Service    INTERIEUR  SUD COMOE  69bdfc69fd  8a1e6ce31f
# 1506  ASSINIE  In Service    INTERIEUR  SUD COMOE  69bdfc69fd  8a1e6ce31f
# 1507  ASSINIE  In Service    INTERIEUR  SUD COMOE  69bdfc69fd  8a1e6ce31f
#
#        cell_id_y            datetime product   site_id_y  value       date  \
# 1503  d250ec4e98 2012-05-07 08:00:05   Voice  69bdfc69fd    807 2012-05-07
# 1504  f76d889a00 2012-05-07 08:00:06   Voice  69bdfc69fd    300 2012-05-07
# 1505  d250ec4e98 2012-05-07 08:00:07   Voice  69bdfc69fd    120 2012-05-07
# 1506  f76d889a00 2012-05-07 08:00:08   Voice  69bdfc69fd     94 2012-05-07
# 1507  d250ec4e98 2012-05-07 08:00:08   Voice  69bdfc69fd     15 2012-05-07
#
#           time
# 1503  08:00:05
# 1504  08:00:06
# 1505  08:00:07
# ...

# %%
workinghrs.groupby('cities')['cities'].count().sort_values(ascending = False)
# Out:
# cities
# BOUAKE           625077
# SAN-PEDRO        345754
# DALOA            222048
# MAN              187717
# ABOBO            182984
# DIVO             181058
# BOUNA            178039
# GRAND-BASSAM     144719
# DABOU            134275
# ASSINIE          130891
# AGNIBILEKRO      110500
# COCODY           109344
# ADZOPE           106197
# ABOISSO           99367
# DJEMISSIKRO       92346
# DAOUKRO           87036
# BONOUA            83158
# DABAKALA          81004
# GAGNOA            72917
# BOUNDIALI         67933
# DJEBONOUA         64078
# BOUAFLE           57657
# YAMOUSSOUKRO      56077
# N'ZIKRO           50000
# GRAND BEREBY      48857
# BONON             48068
# NOE               47021
# ATTINGUIE         45729
# SEGUELA           45608
# MEADJI            44112
#                   ...
# BOCANDA               6
# BANGOLO               5
# TABAGNE               5
# DIABO                 5
# RUBINO                5
# GOHITAFLA             4
# RAVIART               4
# ...

# %%
#not working hours between 5am and 8am
nworkinghrs =mergedsample[(mergedsample.datetime.dt.time <= datetime.time(17)) & (mergedsample.datetime.dt.time >= datetime.time(8))]

nworkinghrs.head()
# Out:
#        cities      status localisation     region   cell_id_x   site_id_x  \
# 1503  ASSINIE  In Service    INTERIEUR  SUD COMOE  69bdfc69fd  8a1e6ce31f
# 1504  ASSINIE  In Service    INTERIEUR  SUD COMOE  69bdfc69fd  8a1e6ce31f
# 1505  ASSINIE  In Service    INTERIEUR  SUD COMOE  69bdfc69fd  8a1e6ce31f
# 1506  ASSINIE  In Service    INTERIEUR  SUD COMOE  69bdfc69fd  8a1e6ce31f
# 1507  ASSINIE  In Service    INTERIEUR  SUD COMOE  69bdfc69fd  8a1e6ce31f
#
#        cell_id_y            datetime product   site_id_y  value       date  \
# 1503  d250ec4e98 2012-05-07 08:00:05   Voice  69bdfc69fd    807 2012-05-07
# 1504  f76d889a00 2012-05-07 08:00:06   Voice  69bdfc69fd    300 2012-05-07
# 1505  d250ec4e98 2012-05-07 08:00:07   Voice  69bdfc69fd    120 2012-05-07
# 1506  f76d889a00 2012-05-07 08:00:08   Voice  69bdfc69fd     94 2012-05-07
# 1507  d250ec4e98 2012-05-07 08:00:08   Voice  69bdfc69fd     15 2012-05-07
#
#           time
# 1503  08:00:05
# 1504  08:00:06
# 1505  08:00:07
# ...

# %%
nworkinghrs.groupby('cities')['cities'].count().sort_values(ascending = False)
# Out:
# cities
# BOUAKE           625077
# SAN-PEDRO        345754
# DALOA            222048
# MAN              187717
# ABOBO            182984
# DIVO             181058
# BOUNA            178039
# GRAND-BASSAM     144719
# DABOU            134275
# ASSINIE          130891
# AGNIBILEKRO      110500
# COCODY           109344
# ADZOPE           106197
# ABOISSO           99367
# DJEMISSIKRO       92346
# DAOUKRO           87036
# BONOUA            83158
# DABAKALA          81004
# GAGNOA            72917
# BOUNDIALI         67933
# DJEBONOUA         64078
# BOUAFLE           57657
# YAMOUSSOUKRO      56077
# N'ZIKRO           50000
# GRAND BEREBY      48857
# BONON             48068
# NOE               47021
# ATTINGUIE         45729
# SEGUELA           45608
# MEADJI            44112
#                   ...
# BOCANDA               6
# BANGOLO               5
# TABAGNE               5
# DIABO                 5
# RUBINO                5
# GOHITAFLA             4
# RAVIART               4
# ...

# %%
#sort products by values so see those that are making more for the company
mergedsample.groupby('product')['product'].count().sort_values(ascending = False)
# Out:
# product
# Voice    8628796
# sms       325042
# data       94107
# Name: product, dtype: int64
